# %% [markdown]
# #### 1. Install and authenticate the Databricks CLI using OAuth U2M against your workspace.

# %% [markdown]
# ```
# Last login: Fri Sep  4 15:37:38 on ttys001
# manpreetsingh@Manpreet ~ % databricks auth login --host https://dbc-38bddc5d-02cf.cloud.databricks.com
# Databricks profile name [dbc-38bddc5d-02cf]: botmanpreet
# Profile botmanpreet was successfully saved
# ```

# %% [markdown]
# #### 2. Initialize a Declarative Automation Bundle project (databricks bundle init, or by hand) with one job resource.

# %% [markdown]
# ```bash
# Created

# %% [markdown]
# #### 3. Run databricks bundle validate and databricks bundle deploy -t dev, then confirm the job appears in your workspace.

# %% [markdown]
# ```bash
# Workspace/Users/botmanpreet2021@gmail.com/databricks-assignments/Day9-Assignment$ cd day_9_DABs
# Workspace/Users/botmanpreet2021@gmail.com/databricks-assignments/Day9-Assignment/day_9_DABs$ databricks bundle validate
# Name: day_9_DABs
# Target: dev
# Workspace:
#   Host: http://127.0.0.1:7073
#   User: botmanpreet2021@gmail.com
#   Path: /Workspace/Users/botmanpreet2021@gmail.com/.bundle/day_9_DABs/dev
#
# Validation OK!
# Workspace/Users/botmanpreet2021@gmail.com/databricks-assignments/Day9-Assignment/day_9_DABs$ databricks bundle deploy -t dev
# Source-linked deployment is enabled. Deployed resources reference the source files in your working tree instead of separate copies.
# Created jobs.sample_job
# Files: 0 uploaded, 0 deleted
# Resources: 1 created, 0 changed, 0 deleted, 0 unchanged
