-- %% [markdown]
-- #### 4. Add a filter to your dashboard (e.g., by region or date range) and confirm both visualizations respond to it.

-- %% [markdown]
-- ![Screenshot 2026-09-15 at 12.05.26 PM.png](./Screenshot 2026-09-15 at 12.05.26 PM.png "Screenshot 2026-09-15 at 12.05.26 PM.png")

-- %% [markdown]
-- #### 5. Set up a Genie Agent scoped to your sales tables: write at least 2 instructions and 2 sample queries to steer its behavior.

-- %% [markdown]
-- ```bash
-- * before telling anything, verfify the data columns first.
-- * Always say no or you don't know if something is missing, communicate honestly

-- %% [markdown]
-- ![Screenshot 2026-09-15 at 12.17.51 PM.png](./Screenshot 2026-09-15 at 12.17.51 PM.png "Screenshot 2026-09-15 at 12.17.51 PM.png")

-- %% [markdown]
-- ![Screenshot 2026-09-15 at 12.20.06 PM.png](./Screenshot 2026-09-15 at 12.20.06 PM.png "Screenshot 2026-09-15 at 12.20.06 PM.png")

-- %% [markdown]
-- #### 6. Ask your Genie Agent a question it initially answers incorrectly or vaguely, then improve its instructions/sample queries/trusted assets until it answers correctly — document the before and after.

-- %% [markdown]
-- Data is limited and so the answers are correct all the time
