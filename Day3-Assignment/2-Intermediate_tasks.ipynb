-- %% [markdown]
-- #### 4. Add _metadata.file_name and _metadata.file_path to your ingestion query and use them to prove which source file each row came from.

-- %%
-- Always first see the data
select * from read_files('/Volumes/cyntexa_dev/sales/raw/circuits.csv')

-- %%
create or replace table cyntexa_dev.sales.circuits_csv as 
select circuitId, circuitRef, name, location, country, lat, lng, alt, url, _metadata.file_name, _metadata.file_path
from read_files('/Volumes/cyntexa_dev/sales/raw/circuits.csv')

-- %%
select * from cyntexa_dev.sales.circuits_csv limit 5--

-- %%
-- reading the json file 
select * from read_files('/Volumes/cyntexa_dev/sales/raw/drivers.json') limit 5

-- %%
create or replace table cyntexa_dev.sales.drivers_json as 
select code, dob, driverId, driverRef, name.forename, name.surname, nationality, number, url, _metadata.file_name, _metadata.file_path
from read_files('/Volumes/cyntexa_dev/sales/raw/drivers.json')

-- %%
select * from cyntexa_dev.sales.drivers_json limit 5

-- %% [markdown]
-- #### 5. Create an Iceberg table from the same source data and compare its DESCRIBE DETAIL output (format, location) to the Delta version.

-- %%
create table cyntexa_dev.sales.drivers_json_iceberg using ICEBERG as 
select code, dob, driverId, driverRef, name.forename, name.surname, nationality, number, url, _metadata.file_name, _metadata.file_path
from read_files('/Volumes/cyntexa_dev/sales/raw/drivers.json')

-- %%
describe detail cyntexa_dev.sales.drivers_json_iceberg

-- %% [markdown]
-- #### 6. (Data Analyst) Write a query using the metadata columns to build a 'records per source file' audit report — useful for verifying a vendor's daily file drop.

-- %%
%python
df = spark.read.format('json').load('/Volumes/cyntexa_dev/sales/raw/drivers.json').select("_metadata")
display(df)

-- %%
%python
df = spark.read.format('csv').load('/Volumes/cyntexa_dev/sales/raw/circuits.csv').select("_metadata")
display(df)
