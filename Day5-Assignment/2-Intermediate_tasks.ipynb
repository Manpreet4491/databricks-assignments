# %% [markdown]
# #### 4. Build a cleaning pipeline: drop fully-null rows, fill remaining nulls with sensible defaults, remove exact duplicates, and sort by order_date.

# %%
import pyspark.sql.functions as F

df = spark.read.csv(
    '/Volumes/cyntexa_dev/sales/raw/orders_falsy.csv',
    header=True,
    inferSchema=True
)
df.display()

# %%
df = df.dropna('all').fillna({'email': 'unknown@gmail.com', 'discount': 0}).dropDuplicates().sort("order_date")
df.display()

# %% [markdown]
# #### 5. Perform an aggregation (revenue by category or region) and a join against a second small reference table (e.g., customers or regions).

# %%
from pyspark.sql import functions as F

orders = spark.read.table('samples.tpch.orders')
df = spark.read.table('samples.tpch.customer')\
    .join(orders, F.col('c_custkey') == F.col('o_custkey'), 'left').limit(100)

df.display()

# %% [markdown]
# #### 6. Create a feature branch in your Databricks Repo, change the cleaning logic, and open a pull request describing what changed and why.

# %% [markdown]
# - Pushed the current changes into main branch
# - Created a feature branch
# - Push all the changes into feature branch
# -
